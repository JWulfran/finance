# %%
#Import the library 
import numpy as np 
#import sympy as sp 
import scipy as sci 
import matplotlib.pyplot as plt

# %%
x = np.arange(-20, 20,0.1)
Y = 2*x**2 +20*x -22
# Out:
# array([ 3.78000000e+02,  3.72020000e+02,  3.66080000e+02,  3.60180000e+02,
#         3.54320000e+02,  3.48500000e+02,  3.42720000e+02,  3.36980000e+02,
#         3.31280000e+02,  3.25620000e+02,  3.20000000e+02,  3.14420000e+02,
#         3.08880000e+02,  3.03380000e+02,  2.97920000e+02,  2.92500000e+02,
#         2.87120000e+02,  2.81780000e+02,  2.76480000e+02,  2.71220000e+02,
#         2.66000000e+02,  2.60820000e+02,  2.55680000e+02,  2.50580000e+02,
#         2.45520000e+02,  2.40500000e+02,  2.35520000e+02,  2.30580000e+02,
#         2.25680000e+02,  2.20820000e+02,  2.16000000e+02,  2.11220000e+02,
#         2.06480000e+02,  2.01780000e+02,  1.97120000e+02,  1.92500000e+02,
#         1.87920000e+02,  1.83380000e+02,  1.78880000e+02,  1.74420000e+02,
#         1.70000000e+02,  1.65620000e+02,  1.61280000e+02,  1.56980000e+02,
#         1.52720000e+02,  1.48500000e+02,  1.44320000e+02,  1.40180000e+02,
# ...

# %%
#Optimisation d'une fct à une seule variable 
i = 0 
while Y[i]> Y[i+1]:
    i = i + 1

plt.plot(x, Y)
plt.scatter(x[i], Y[i])
plt.grid()
